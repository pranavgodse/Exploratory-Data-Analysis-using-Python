# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#         <td width="15%">
#             <img src="in_class.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b> Inclass - Lab <br>(Day 3)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### About the dataset (Adult Income Data)
#
# The dataset contains information about the individuals' age, gender, and several attributes affecting the income of a person. <br> Attribute information:
#
# **age:** Age of an individual
#
# **workclass:** Working class of the individual
#
# **fnlwgt:** Weights based on the demographic characteristics
#
# **education:** Highest education of the individual
#
# **education.num:** Education encoded with unique numbers
#
# **marital.status:** Marital status of the individual
#
# **occupation:** Occupation of the individual
#
# **relationship:** Relation of the individual in the family
#
# **race:** Race of the individual
#
# **sex:** Gender of the individual
#
# **capital.gain:** Gain amount of the individual
#
# **capital.loss:** Loss amount of the individual
#
# **hours.per.week:** Working hours per week
#
# **native.country:** The native country of the individual
#
# **income:** Income of the individual

# %% [markdown]
# ##  Table of Content
#
# 1. **[Quantitative and Quantitative Analysis](#quan)**
# 2. **[Categorical and Quantitative Analysis](#catquan)**
# 3. **[Categorical and Categorical Analysis](#cat)**

# %% [markdown]
# **Import the required libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Load the adult dataset and check the first five observations

# %%
df = pd.read_csv('adult.csv')
df.head(5)
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# 1          4356              18  United-States  <=50K
# 2          4356              40  United-States  <=50K
# 3          3900              40  United-States  <=50K
# 4          3900              40  United-States  <=50K

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <a id="quan"> </a>
# ## 1. Quantitative and Quantitative Analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>1. Is there any effect of a person's age on the working hours</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
sns.scatterplot(df['age'], df['hours.per.week'])
# Out:
# C:\Users\prana\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='hours.per.week'>

# %% [markdown]
# There is no relationship between age and workin hours.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>2. Analyze the trend of the capital gain amount for different educational qualifications</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize = (10,5))
df.groupby(['education'])['capital.gain'].mean().plot()
# Out:
# <AxesSubplot:xlabel='education'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3. Check the effect of working hours of individuals on capital gain </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize = (10,5))
sns.scatterplot(df['hours.per.week'], df['capital.gain'])
plt.show()
# Out:
# C:\Users\prana\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>4.  Find the trend in the average working hours corresponding to the age of an individual</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df.groupby(['age'])['hours.per.week'].mean().plot()
plt.show()

# %% [markdown]
# As the age increases the working hours increases, after 60 years the working hours decreases. Few elderly people are working for more than 30 hours

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>5. Check the distribution of the average capital loss corresponding to the age</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df.groupby(['age'])['capital.loss'].mean().plot()
# Out:
# <AxesSubplot:xlabel='age'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>6. Is there a negative relation between capital gain and age?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
sns.scatterplot(df['age'], df['capital.gain'])
# Out:
# C:\Users\prana\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='capital.gain'>

# %% [markdown]
# There is no corelation between capital gain and age.

# %% [markdown]
# <a id="catquan"> </a>
# ## 2. Categorical and Quantitative Analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>7. Compare the average age with levels of income </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
sns.barplot(x='income',y='age', data = df)
# Out:
# <AxesSubplot:xlabel='income', ylabel='age'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>8. Check the distribution of working hours with respect to the gender of the individual</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize = (10,5))
sns.violinplot(x = 'sex', y = 'hours.per.week', data = df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='hours.per.week'>

# %% [markdown]
# Working hours for male are more than those for female

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>9. Compare the income of individuals based on their education</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(10,10))


sns.boxplot(x = 'income', y = 'education.num', data = df)
# Out:
# <AxesSubplot:xlabel='income', ylabel='education.num'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>10. Find the average age of males and females</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
sns.barplot(x = 'sex', y = 'age', data = df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>11. Compare the distribution of working hours for the distinct classes of income
#  </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
sns.boxplot(x = 'income', y = 'hours.per.week', data = df)
# Out:
# <AxesSubplot:xlabel='income', ylabel='hours.per.week'>

# %% [markdown]
# Based on income the working hours vary. Both the income categories have outliers.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>12. Identify wheather the distributions of age based on the gender and race of the individual are positively skewed or not
#  </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(10,5))

sns.violinplot(x= 'race', y = 'age', data = df, hue = 'sex', split = 'sex')

plt.show()

# %%
plt.figure(figsize=(10,5))

sns.boxplot(x= 'race', y = 'age', data = df, hue = 'sex')

plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>13. Compare the working hours for each working class</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(15,5))

sns.barplot(x= 'workclass', y = 'hours.per.week', data = df)

plt.show()

# %% [markdown]
# Based on the profession, the working hours vary. A high proportion of federal govt. employees are working for nearly 40 hours

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>14. Compare the weightage based on demographic characteristics by gender</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(10,5))

sns.boxplot(x= 'sex', y = 'fnlwgt', data = df)

plt.show()

# %% [markdown]
# The gender does not influence the demographic characteristics

# %% [markdown]
# <a id="cat"> </a>
# ## 3. Categorical and Categorical Analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>15. Study the variation in income by gender</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
pd.crosstab(df['sex'],df['income']).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='sex'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>16. Compare the income by race</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
pd.crosstab(df['race'], df['income'], normalize ='index')
# Out:
# income                 <=50K      >50K
# race
# Amer-Indian-Eskimo  0.884244  0.115756
# Asian-Pac-Islander  0.734360  0.265640
# Black               0.876120  0.123880
# Other               0.907749  0.092251
# White               0.744140  0.255860

# %%
pd.crosstab(df['race'], df['income']).plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='race'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>17. Is there an all male profession according to the data?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
s = pd.pivot_table(df, values='age', index='occupation', columns='sex',aggfunc='mean')

sns.set_palette("Set2", 10, .75)

fig = s.plot.bar(stacked = True, figsize = (10,5))

fig.legend(loc = 'upper right')

plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>18. How does income vary with working class?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
pd.crosstab(df['workclass'], df['income'], normalize = 'all')
# Out:
# income               <=50K      >50K
# workclass
# ?                 0.050521  0.005866
# Federal-gov       0.018089  0.011394
# Local-gov         0.045330  0.018949
# Never-worked      0.000215  0.000000
# Private           0.544609  0.152422
# Self-emp-inc      0.015172  0.019103
# Self-emp-not-inc  0.055803  0.022235
# State-gov         0.029022  0.010841
# Without-pay       0.000430  0.000000

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>19. How is income related to marital status?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
pd.crosstab(df['marital.status'], df['income'])
# Out:
# income                 <=50K  >50K
# marital.status
# Divorced                3980   463
# Married-AF-spouse         13    10
# Married-civ-spouse      8284  6692
# Married-spouse-absent    384    34
# Never-married          10192   491
# Separated                959    66
# Widowed                  908    85

# %%
pd.crosstab(df['marital.status'], df['income']).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='marital.status'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>20. Compare the income for different occupations</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
pd.crosstab(df['occupation'], df['income'])
# Out:
# income             <=50K  >50K
# occupation
# ?                   1652   191
# Adm-clerical        3263   507
# Armed-Forces           8     1
# Craft-repair        3170   929
# Exec-managerial     2098  1968
# Farming-fishing      879   115
# Handlers-cleaners   1284    86
# Machine-op-inspct   1752   250
# Other-service       3158   137
# Priv-house-serv      148     1
# Prof-specialty      2281  1859
# Protective-serv      438   211
# Sales               2667   983
# Tech-support         645   283
# Transport-moving    1277   320

# %%
pd.crosstab(df['occupation'], df['income'], normalize = 'index')
# Out:
# income                <=50K      >50K
# occupation
# ?                  0.896365  0.103635
# Adm-clerical       0.865517  0.134483
# Armed-Forces       0.888889  0.111111
# Craft-repair       0.773359  0.226641
# Exec-managerial    0.515986  0.484014
# Farming-fishing    0.884306  0.115694
# Handlers-cleaners  0.937226  0.062774
# Machine-op-inspct  0.875125  0.124875
# Other-service      0.958422  0.041578
# Priv-house-serv    0.993289  0.006711
# Prof-specialty     0.550966  0.449034
# Protective-serv    0.674884  0.325116
# Sales              0.730685  0.269315
# Tech-support       0.695043  0.304957
# Transport-moving   0.799624  0.200376

# %%
pd.crosstab(df['occupation'], df['income']).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='occupation'>
